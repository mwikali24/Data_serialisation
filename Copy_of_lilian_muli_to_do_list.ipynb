# %%
def to_do_list_menu():
    """Display the main menu."""
    print("\n Welcome to my to_do_list_menu")
    print("1. Add Task")
    print("2. Mark Task as Completed")
    print("3. List Tasks")
    print("4. Remove Task")
    print("5. Quit")

to_do_list_menu()
# Out:
#  Welcome to my to_do_list_menu
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit

# %%
tasks = tasks = [
    ("shower", False),
    ("finish presentation for work", False),
    ("find mom's birthday present", False),
    ("undertake house chores", False),
    ("watch a movie", False)
]
def tasks_to_do_status(tasks):
    """Display all tasks with their completion status."""
    if not tasks:
        print("\nNo tasks in the list.")
    else:
        print("\nTasks:")
        for index, (task, completed) in enumerate(tasks, start=1):
          status = "Completed" if completed else "Not Completed"
        print(f"{index}. {task} [{status}]")
tasks_to_do_status(tasks)
# Out:
# Tasks:
# 5. watch a movie [Not Completed]

# %%
tasks = [
        "shower",
        "finish presentation for work",
        "find mom's birthday present",
        "undertake house chores",
        "watch a movie"
    ]
def tasks_to_do(tasks):
    """Add a new task to the list."""
    task_description = input("\nEnter the task description: ").strip()
    if task_description:
        tasks.append((task_description, False))
        print(f"Task '{task_description}' added.")
    else:
        print("Task description cannot be empty.")
tasks_to_do(tasks)
# Out:
# Enter the task description: "watch a movie"
# Task '"watch a movie"' added.

# %%
def to_do_list_menu():
    """Display to_do_list_menu."""
    print("\nTo-Do List Menu")
    print("1. Add Task")
    print("2. Mark Task as Completed")
    print("3. List Tasks")
    print("4. Remove Task")
    print("5. Quit")

def tasks_to_do(tasks):
    """Display all tasks whether done or not done."""
    if not tasks:
        print("\nNo tasks in the list.")
    else:
        print("\nTasks:")
        for index, (description, done) in enumerate(tasks, start=1):
            status = "done" if done else "not done"
            print(f"{index}. {description} [{status}]")

def add_task(tasks):

    task_description = input("\nEnter the task description: ").strip()
    if task_description:
        tasks.append((task_description, False))
        print(f"Task '{task_description}' added.")
    else:
        print("Task description cannot be empty.")

def tasks_completed(tasks):
    """Mark a task as done."""
    tasks_to_do(tasks)
    if tasks:
        try:
            task_num = int(input("\nEnter the task number to mark as done: "))
            if 1 <= task_num <= len(tasks):
                task, done = tasks[task_num - 1]
                if done:
                    print(f"Task '{task}' is already marked as done.")
                else:
                    tasks[task_num - 1] = (task, True)
                    print(f"Task '{task}' marked as done.")
            else:
                print("Invalid task number.")
        except ValueError:
            print("Please enter a valid number.")

def remove_task(tasks):

    tasks_to_do(tasks)
    if tasks:
        try:
            task_num = int(input("\nEnter the task number to remove: "))
            if 1 <= task_num <= len(tasks):
                removed_task, _ = tasks.pop(task_num - 1)
                print(f"Task '{removed_task}' removed.")
            else:
                print("Invalid task number.")
        except ValueError:
            print("Please enter a valid number.")

def main():
    """Main function to run the to-do list manager."""
    tasks = []
    while True:
        to_do_list_menu()
        choice = input("\nChoose an option: ").strip()
        if choice == '1':
            add_task(tasks)
        elif choice == '2':
            tasks_completed(tasks)
        elif choice == '3':
            tasks_to_do(tasks)
        elif choice == '4':
            remove_task(tasks)
        elif choice == '5':
            print("that's a trial")
            break
        else:
            print("Not among the choices. Please choose one of the above choices.")

if __name__ == "__main__":
    main()
# Out:
# To-Do List Menu
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
#
# Choose an option: 1
#
# Enter the task description: shower
# Task 'shower' added.
#
# To-Do List Menu
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
#
# Choose an option: 1
#
# Enter the task description: finish presentation for work
# Task 'finish presentation for work' added.
#
# To-Do List Menu
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
#
# Choose an option: 1
#
# Enter the task description: find mom's birthday present
# Task 'find mom's birthday present' added.
#
# To-Do List Menu
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
#
# Choose an option: 1
#
# Enter the task description: undertake house chores
# Task 'undertake house chores' added.
#
# To-Do List Menu
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
#
# ...

# %% [markdown]
# This was a to_do_list for a day,,intented activities were 5,,made to accomplish 4 activities that i marked as done.Removed one activity.
# the code instructed me to choose an option,,then after enter the number description of what i want to do (for task) to edit.
# finally choose the the option (5) to quit.
